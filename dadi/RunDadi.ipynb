# %%
import dadi
matplotlib.use('TkAgg')
import matplotlib
% matplotlib inline

# %% [markdown]
# Loading in already-made Spectrum file

# %%
fsTonk = dadi.Spectrum.from_file("MaxSeg/dadi/tonkawae-36.sfs")
fsNauf = dadi.Spectrum.from_file("MaxSeg/dadi/naufragia-8.sfs")
fsChis = dadi.Spectrum.from_file("MaxSeg/dadi/chisholmensis-14.sfs")
fs2TonkNauf = dadi.Spectrum.from_file("MaxSeg/dadi/naufragia-tonkawae.sfs")
fs2TonkChis = dadi.Spectrum.from_file("MaxSeg/dadi/chisholmensis-tonkawae.sfs")
fs2NaufChis = dadi.Spectrum.from_file("MaxSeg/dadi/chisholmensis-naufragia.sfs")
fs3 = dadi.Spectrum.from_file("MaxSeg/dadi/chisholmensis-naufragia-tonkawae.sfs")

# %%
print(fsTonk.sample_sizes)
print(fsNauf.sample_sizes)
print(fsChis.sample_sizes)
# Out:
# [36]
# [8]
# [14]

# %%
dadi.Plotting.plot_1d_fs(fsTonk)

# %%
dadi.Plotting.plot_1d_fs(fsNauf)

# %%
dadi.Plotting.plot_1d_fs(fsChis)

# %%
dadi.Plotting.plot_single_2d_sfs(fs2TonkChis, vmin=1)

# %%
dadi.Plotting.plot_single_2d_sfs(fs2NaufChis, vmin=1)

# %%
dadi.Plotting.plot_single_2d_sfs(fs2TonkNauf)

# %%
fs2TonkChis.S()
# Out:
# 2950.9018617490547

# %% [markdown]
# ## First Scenario: ((chis+nauf)tonk) with continuous gene flow chis <-> nauf

# %%
def FlowChisNauf(params, ns, pts):
    
    # first thing is always to define search grid
    xx = dadi.Numerics.default_grid(pts)
    
    # define list of free parameters to optimize
    N1, N2, N3, T2, T1, m12, m21 = params
